# %%
# !pip install pycaret pandas shap
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached pandas-1.4.2-cp39-cp39-win_amd64.whl (10.5 MB)
# ...
#   Using cached shap-0.40.0-cp39-cp39-win_amd64.whl (432 kB)
# ...
#   Using cached scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
# ...
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached mlflow-1.26.1-py3-none-any.whl (17.8 MB)
# ...
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# ...

# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv("CleanData")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df = pd.read_csv("CleanData")
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Ebolo

# %%
# !pip install pandas

# %%
df = pd.read_csv("CleanData")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df = pd.read_csv("CleanData")
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('CleanData')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df = pd.read_csv('CleanData')
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('CleanData.xlsx')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df = pd.read_csv('CleanData.xlsx')
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('CleanData.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 df = pd.read_csv('CleanData.csv')
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_excel ('CleanData.xlsx', sheet_name='Sheet1')
print (df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
df = pd.read_excel (r'CleanData.xlsx', sheet_name='Sheet1')
print (df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel (r'CleanData.xlsx', sheet_name='Sheet1')
print (df)
# Out:
#       S/NO  Gender  Age                                          Address  \
# 0      NaN     NaN  NaN                                              NaN
# 1      1.0    Male   51  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA
# 2      2.0  Female   40  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA
# 3      3.0  Female   16  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA
# 4      4.0    Male   10  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA
# ..     ...     ...  ...                                              ...
# 292  292.0       F   39     48 UNITY STREET, OFF GOVERNORS ROAD, IKOTUN.
# 293  293.0       M   44     48 UNITY STREET, OFF GOVERNORS ROAD, IKOTUN.
# 294  294.0       F   34           40, Eniitan street, Agunda, Surelere,
# 295  295.0       M   32                                              IDH
# 296  296.0       F   26         OPP PLEKO HOSTEL, MAYFAIR ROUNDABOUT,IFE
#
#      State            SourceCase DateLastContact       LGA       Phone  HCW  \
# ...

# %%
df.head()
# Out:
#    S/NO  Gender  Age                                          Address  State  \
# 0   NaN     NaN  NaN                                              NaN    NaN
# 1   1.0    Male   51  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA  LAGOS
# 2   2.0  Female   40  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA  LAGOS
# 3   3.0  Female   16  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA  LAGOS
# 4   4.0    Male   10  NO 2 OLAGOKE STREET, SUPER BUS STOP, ABULE EGBA  LAGOS
#
#        SourceCase DateLastContact    LGA       Phone  HCW  ... Unnamed: 30  \
# 0             NaN             NaN    NaN         NaN  NaN  ...          18
# 1  DR ADEJORO IGE           41855  AGEGE  8055514314   No  ...        36.8
# 2  DR ADEJORO IGE           41855  AGEGE  7058588437   No  ...        36.7
# 3  DR ADEJORO IGE           41855  AGEGE         NaN   No  ...        37.2
# 4  DR ADEJORO IGE           41855  AGEGE         NaN   No  ...        35.4
#
# ...

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df.show()
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.shape
# Out:
# (297, 40)

# %%
import matplotlib.pyplot as plt
df.plot()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 import matplotlib.pyplot as plt
#       2 df.plot()
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.4/55.4 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 4.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 930.9/930.9 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
df.plot()

plt.show()

# %%
import matplotlib.pyplot as plt

df.plot()
# Out:
# <AxesSubplot:>

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 df.show()
#
# File C:\Users\john.ansa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# ...
#   Using cached cufflinks-0.17.3.tar.gz (81 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
# ...
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [317 lines of output]
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
# ...

# %%
from pycaret.datasets import get_data
dataset = get_data('iris')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 from pycaret.datasets import get_data
#       2 dataset = get_data('iris')
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
# ...
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# ...
#   Using cached numba-0.54.1-cp39-cp39-win_amd64.whl (2.3 MB)
# ...
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# ...
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# ...
#   Using cached pyod-1.0.1.tar.gz (120 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# ...
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
# ...

# %%
# !pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached gensim-3.8.3.tar.gz (23.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# ...
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [317 lines of output]
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.datasets import get_data
dataset = get_data('iris')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 from pycaret.datasets import get_data
#       2 dataset = get_data('iris')
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
pip list
# Out:
# Package              Version
# -------------------- -----------
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                21.4.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               5.0.0
# bs4                  0.0.1
# camelcase            0.2
# certifi              2021.10.8
# cffi                 1.15.0
# charset-normalizer   2.0.12
# click                8.0.1
# colorama             0.4.4
# cycler               0.11.0
# debugpy              1.6.0
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# et-xmlfile           1.1.0
# executing            0.8.3
# fastjsonschema       2.15.3
# fonttools            4.33.3
# idna                 3.3
# ipykernel            6.13.1
# ipython              8.4.0
# ipython-genutils     0.2.0
# ipywidgets           7.7.0
# jedi                 0.18.1
# Jinja2               3.1.2
# joblib               1.0.1
# ...

# %%
# !pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached pyod-1.0.1.tar.gz (120 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# ...
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached gensim-3.8.3.tar.gz (23.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached umap-learn-0.5.3.tar.gz (88 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# ...

# %%
import sys
# !{sys.executable} -m pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# ...
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# ...
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached umap-learn-0.5.3.tar.gz (88 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
pip install pycaret-ts-alpha
# Out:
# ...
#      -------------------------------------- 468.1/468.1 kB 1.2 MB/s eta 0:00:00
# ...
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# ...
#      ---------------------------------------- 6.5/6.5 MB 3.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 601.9/601.9 kB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.4/7.4 MB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.4/2.4 MB 3.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 43.8/43.8 kB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.1/9.1 MB 3.7 MB/s eta 0:00:00
# ...
#   Using cached plotly-5.8.2-py2.py3-none-any.whl (15.2 MB)
# ...
#   Using cached pyod-1.0.1.tar.gz (120 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 69.1/69.1 kB ? eta 0:00:00
# ...
#      -------------------------------------- 199.3/199.3 kB 2.4 MB/s eta 0:00:00
# ...
